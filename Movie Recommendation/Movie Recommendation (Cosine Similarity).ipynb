# %% [markdown]
# # Content-Based Movie Recommendation System

# %% [markdown]
# The goal of this notebook is to build a **Content-Based Movie Recommendation System** that provides personalized movie suggestions based on what users have watched and their interests.
# By analyzing the content features of movies such as: genres, cast, crew, plot keywords, the system will recommend movies that share similar attributes.
#
# The system will use 3 datasets that have been pre-cleaned and stored in the cleaned folder:
# - movie_metadata.csv: Contains detailed information such as title, genres, ratings, of each movie.
# - movie_credits.csv: Includes cast and crew details for each movie.
# - movie_keywords.csv: Set of keywords related to the theme or plot of the movie.
#
# Using these datasets, the system will utilize tex vectorization and cosine similarity to calculate similarty scores between movies.

# %% [markdown]
# ### Loading and Preparing the Data

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Show full content in each cell
#pd.set_option('display.max_colwidth', None)
#pd.set_option('display.max_rows', None)  # Show all rows
#pd.set_option('display.max_columns', None)  # Show all columns
# Reset the display options to their default values
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.max_colwidth')

# %%
movies_metadata = pd.read_csv("cleaned/movies_metadata.csv")
movies_keywords = pd.read_csv("cleaned/movie_keywords.csv")
movies_credits = pd.read_csv("cleaned/movie_credits.csv")

# %%
movies_metadata
# Out:
#        adult           belongs_to_collection      budget  \
# 0      False            Toy Story Collection  30000000.0
# 1      False                             NaN  65000000.0
# 2      False       Grumpy Old Men Collection         NaN
# 3      False                             NaN  16000000.0
# 4      False  Father of the Bride Collection         NaN
# ...      ...                             ...         ...
# 45428  False                             NaN         NaN
# 45429  False                             NaN         NaN
# 45430  False                             NaN         NaN
# 45431  False                             NaN         NaN
# 45432  False                             NaN         NaN
#
#                            genres                              homepage  \
# 0       Animation, Comedy, Family  http://toystory.disney.com/toy-story
# 1      Adventure, Fantasy, Family                                   NaN
# 2                 Romance, Comedy                                   NaN
# 3          Comedy, Drama, Romance                                   NaN
# 4                          Comedy                                   NaN
# ...                           ...                                   ...
# 45428               Drama, Family  http://www.imdb.com/title/tt6209470/
# 45429                       Drama                                   NaN
# 45430     Action, Drama, Thriller                                   NaN
# 45431                         NaN                                   NaN
# 45432                         NaN                                   NaN
#
#              id    imdb_id original_language               original_title  \
# 0         862.0  tt0114709                en                    Toy Story
# 1        8844.0  tt0113497                en                      Jumanji
# 2       15602.0  tt0113228                en             Grumpier Old Men
# 3       31357.0  tt0114885                en            Waiting to Exhale
# 4       11862.0  tt0113041                en  Father of the Bride Part II
# ...         ...        ...               ...                          ...
# 45428  439050.0  tt6209470                fa                      رگ خواب
# 45429  111109.0  tt2028550                tl          Siglo ng Pagluluwal
# 45430   67758.0  tt0303758                en                     Betrayal
# 45431  227506.0  tt0008536                en          Satana likuyushchiy
# 45432  461257.0  tt6980792                en                     Queerama
#
#                                                 overview  ...    status  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  Released
# 1      When siblings Judy and Peter discover an encha...  ...  Released
# 2      A family wedding reignites the ancient feud be...  ...  Released
# 3      Cheated on, mistreated and stepped on, the wom...  ...  Released
# 4      Just when George Banks has recovered from his ...  ...  Released
# ...                                                  ...  ...       ...
# 45428        Rising and falling between a man and woman.  ...  Released
# 45429  An artist struggles to finish his work while a...  ...  Released
# 45430  When one of her hits goes wrong, a professiona...  ...  Released
# 45431  In a small town live two brothers, one a minis...  ...  Released
# 45432  50 years after decriminalisation of homosexual...  ...  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45428         Rising and falling between a man and woman
# 45429                                                NaN
# 45430                             A deadly game of wits.
# 45431                                                NaN
# 45432                                                NaN
#
#                              title  video vote_average  vote_count  \
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45428                       Subdue  False          4.0         1.0
# 45429          Century of Birthing  False          9.0         3.0
# 45430                     Betrayal  False          3.8         6.0
# 45431             Satan Triumphant  False          0.0         0.0
# 45432                     Queerama  False          0.0         0.0
#
#           adult_category    budget_category    popularity_category  \
# 0      General Audiences         HighBudget  BlockbusterPopularity
# 1      General Audiences  BlockbusterBudget  BlockbusterPopularity
# 2      General Audiences                NaN  BlockbusterPopularity
# 3      General Audiences         HighBudget         HighPopularity
# 4      General Audiences                NaN  BlockbusterPopularity
# ...                  ...                ...                    ...
# 45428  General Audiences                NaN     UltraLowPopularity
# 45429  General Audiences                NaN     UltraLowPopularity
# 45430  General Audiences                NaN       MediumPopularity
# 45431  General Audiences                NaN     UltraLowPopularity
# 45432  General Audiences                NaN     UltraLowPopularity
#
#          runtime_category
# 0      UltraShortDuration
# 1            HighDuration
# 2            HighDuration
# 3       UltraHighDuration
# 4            HighDuration
# ...                   ...
# 45428       ShortDuration
# 45429   UltraHighDuration
# 45430       ShortDuration
# 45431       ShortDuration
# 45432  UltraShortDuration
#
# [45433 rows x 28 columns]

# %%
movies_keywords
# Out:
#            id                                           keywords
# 0         862  jealousy, toy, boy, friendship, friends, rival...
# 1        8844  board game, disappearance, based on children's...
# 2       15602  fishing, best friend, duringcreditsstinger, ol...
# 3       31357  based on novel, interracial relationship, sing...
# 4       11862  baby, midlife crisis, confidence, aging, daugh...
# ...       ...                                                ...
# 45427  439050                                        tragic love
# 45428  111109                                artist, play, pinoy
# 45429   67758                                                NaN
# 45430  227506                                                NaN
# 45431  461257                                                NaN
#
# [45432 rows x 2 columns]

# %%
movies_credits
# Out:
#                                                     cast  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1      Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2      Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3      Whitney Houston, Angela Bassett, Loretta Devin...
# 4      Steve Martin, Diane Keaton, Martin Short, Kimb...
# ...                                                  ...
# 45427          Leila Hatami, Kourosh Tahami, Elham Korda
# 45428  Angel Aquino, Perry Dizon, Hazel Orencio, Joel...
# 45429  Erika Eleniak, Adam Baldwin, Julie du Page, Ja...
# 45430  Iwan Mosschuchin, Nathalie Lissenko, Pavel Pav...
# 45431                                                NaN
#
#                                                     crew      id
# 0      John Lasseter, Joss Whedon, Andrew Stanton, Jo...     862
# 1      Larry J. Franco, Jonathan Hensleigh, James Hor...    8844
# 2      Howard Deutch, Mark Steven Johnson, Mark Steve...   15602
# 3      Forest Whitaker, Ronald Bass, Ronald Bass, Ezr...   31357
# 4      Alan Silvestri, Elliot Davis, Nancy Meyers, Na...   11862
# ...                                                  ...     ...
# 45427  Hamid Nematollah, Hamid Nematollah, Farshad Mo...  439050
# 45428  Lav Diaz, Lav Diaz, Dante Perez, Lav Diaz, Lav...  111109
# 45429  Mark L. Lester, C. Courtney Joyner, Jeffrey Go...   67758
# 45430              Yakov Protazanov, Joseph N. Ermolieff  227506
# 45431                                      Daisy Asquith  461257
#
# [45432 rows x 3 columns]

# %%
# Add columns that are most relevant for the recommendation systems
columns = ['id', 'original_title', 'title', 'tagline', 'overview', 'belongs_to_collection', 'genres', 'adult_category', 'original_language', 'spoken_languages', 'runtime_category', 'production_companies', 'production_countries', 'budget_category', 'popularity_category']
features = movies_metadata[columns]

# %%
# Merge the main movies_metadata datframe with keywords and casts. Left join to ensure all movies are available.
movies_df = pd.merge(pd.merge(movies_metadata[columns], movies_keywords, how='left', on='id' ), movies_credits, how='left', on='id')

# %%
# Fill na to replace any missing values with empty string as it can cause issues during string concatnation.
movies_df['combined'] = movies_df[columns[1:]].fillna('').astype(str).agg(' '.join, axis=1)
movies_df
# Out:
#              id               original_title                        title  \
# 0         862.0                    Toy Story                    Toy Story
# 1        8844.0                      Jumanji                      Jumanji
# 2       15602.0             Grumpier Old Men             Grumpier Old Men
# 3       31357.0            Waiting to Exhale            Waiting to Exhale
# 4       11862.0  Father of the Bride Part II  Father of the Bride Part II
# ...         ...                          ...                          ...
# 45428  439050.0                      رگ خواب                       Subdue
# 45429  111109.0          Siglo ng Pagluluwal          Century of Birthing
# 45430   67758.0                     Betrayal                     Betrayal
# 45431  227506.0          Satana likuyushchiy             Satan Triumphant
# 45432  461257.0                     Queerama                     Queerama
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45428         Rising and falling between a man and woman
# 45429                                                NaN
# 45430                             A deadly game of wits.
# 45431                                                NaN
# 45432                                                NaN
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45428        Rising and falling between a man and woman.
# 45429  An artist struggles to finish his work while a...
# 45430  When one of her hits goes wrong, a professiona...
# 45431  In a small town live two brothers, one a minis...
# 45432  50 years after decriminalisation of homosexual...
#
#                 belongs_to_collection                      genres  \
# 0                Toy Story Collection   Animation, Comedy, Family
# 1                                 NaN  Adventure, Fantasy, Family
# 2           Grumpy Old Men Collection             Romance, Comedy
# 3                                 NaN      Comedy, Drama, Romance
# 4      Father of the Bride Collection                      Comedy
# ...                               ...                         ...
# 45428                             NaN               Drama, Family
# 45429                             NaN                       Drama
# 45430                             NaN     Action, Drama, Thriller
# 45431                             NaN                         NaN
# 45432                             NaN                         NaN
#
#           adult_category original_language   spoken_languages  \
# 0      General Audiences                en            English
# 1      General Audiences                en  English, Français
# 2      General Audiences                en            English
# 3      General Audiences                en            English
# 4      General Audiences                en            English
# ...                  ...               ...                ...
# 45428  General Audiences                fa              فارسی
# 45429  General Audiences                tl                NaN
# 45430  General Audiences                en            English
# 45431  General Audiences                en                NaN
# 45432  General Audiences                en            English
#
#          runtime_category                               production_companies  \
# 0      UltraShortDuration                            Pixar Animation Studios
# 1            HighDuration  TriStar Pictures, Teitler Film, Interscope Com...
# 2            HighDuration                       Warner Bros., Lancaster Gate
# 3       UltraHighDuration             Twentieth Century Fox Film Corporation
# 4            HighDuration         Sandollar Productions, Touchstone Pictures
# ...                   ...                                                ...
# 45428       ShortDuration                                                NaN
# 45429   UltraHighDuration                                        Sine Olivia
# 45430       ShortDuration                            American World Pictures
# 45431       ShortDuration                                          Yermoliev
# 45432  UltraShortDuration                                                NaN
#
#            production_countries    budget_category    popularity_category  \
# 0      United States of America         HighBudget  BlockbusterPopularity
# 1      United States of America  BlockbusterBudget  BlockbusterPopularity
# 2      United States of America                NaN  BlockbusterPopularity
# 3      United States of America         HighBudget         HighPopularity
# 4      United States of America                NaN  BlockbusterPopularity
# ...                         ...                ...                    ...
# 45428                      Iran                NaN     UltraLowPopularity
# 45429               Philippines                NaN     UltraLowPopularity
# 45430  United States of America                NaN       MediumPopularity
# 45431                    Russia                NaN     UltraLowPopularity
# 45432            United Kingdom                NaN     UltraLowPopularity
#
#                                                 keywords  \
# 0      jealousy, toy, boy, friendship, friends, rival...
# 1      board game, disappearance, based on children's...
# 2      fishing, best friend, duringcreditsstinger, ol...
# 3      based on novel, interracial relationship, sing...
# 4      baby, midlife crisis, confidence, aging, daugh...
# ...                                                  ...
# 45428                                        tragic love
# 45429                                artist, play, pinoy
# 45430                                                NaN
# 45431                                                NaN
# 45432                                                NaN
#
#                                                     cast  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1      Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2      Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3      Whitney Houston, Angela Bassett, Loretta Devin...
# 4      Steve Martin, Diane Keaton, Martin Short, Kimb...
# ...                                                  ...
# 45428          Leila Hatami, Kourosh Tahami, Elham Korda
# 45429  Angel Aquino, Perry Dizon, Hazel Orencio, Joel...
# 45430  Erika Eleniak, Adam Baldwin, Julie du Page, Ja...
# 45431  Iwan Mosschuchin, Nathalie Lissenko, Pavel Pav...
# 45432                                                NaN
#
#                                                     crew  \
# 0      John Lasseter, Joss Whedon, Andrew Stanton, Jo...
# 1      Larry J. Franco, Jonathan Hensleigh, James Hor...
# 2      Howard Deutch, Mark Steven Johnson, Mark Steve...
# 3      Forest Whitaker, Ronald Bass, Ronald Bass, Ezr...
# 4      Alan Silvestri, Elliot Davis, Nancy Meyers, Na...
# ...                                                  ...
# 45428  Hamid Nematollah, Hamid Nematollah, Farshad Mo...
# 45429  Lav Diaz, Lav Diaz, Dante Perez, Lav Diaz, Lav...
# 45430  Mark L. Lester, C. Courtney Joyner, Jeffrey Go...
# 45431              Yakov Protazanov, Joseph N. Ermolieff
# 45432                                      Daisy Asquith
#
#                                                 combined
# 0      Toy Story Toy Story  Led by Woody, Andy's toys...
# 1      Jumanji Jumanji Roll the dice and unleash the ...
# 2      Grumpier Old Men Grumpier Old Men Still Yellin...
# 3      Waiting to Exhale Waiting to Exhale Friends ar...
# 4      Father of the Bride Part II Father of the Brid...
# ...                                                  ...
# 45428  رگ خواب Subdue Rising and falling between a ma...
# 45429  Siglo ng Pagluluwal Century of Birthing  An ar...
# 45430  Betrayal Betrayal A deadly game of wits. When ...
# 45431  Satana likuyushchiy Satan Triumphant  In a sma...
# 45432  Queerama Queerama  50 years after decriminalis...
#
# [45433 rows x 19 columns]

# %%
# Apply TF-IDF Vectorization for text to numerical feature transformation
# Option 1: TFIDF Vectorizer
# Assigns weights to words based on frequency. Common words get lower weights.
# max_df ignores words appearing in more than 90% of the documents. English stop words are used to remove commonly used words without any significnace.
tfidf = TfidfVectorizer(max_df=0.9, stop_words='english')
tfidf_matrix = tfidf.fit_transform(movies_df['combined'])
tfidf_matrix.shape


'''# Option 2: Counts the frequency of words in the text without weighing.
vectorizer = CountVectorizer()
vectorized_matrix = vectorizer.fit_transform(movies_df['combined'])
vectorized_matrix.shape'''
# Out:
# "# Option 2: Counts the frequency of words in the text without weighing.\nvectorizer = CountVectorizer()\nvectorized_matrix = vectorizer.fit_transform(movies_df['combined'])\nvectorized_matrix.shape"

# %%
# Compute cosine similarity
# Option 1
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
# Option 2
# cosine_sim = cosine_similarity(vectorized_matrix, vectorized_matrix)
cosine_sim
# Out:
# array([[1.        , 0.01913877, 0.01486669, ..., 0.00755015, 0.00504998,
#         0.00573448],
#        [0.01913877, 1.        , 0.04071265, ..., 0.06907149, 0.01641236,
#         0.00929048],
#        [0.01486669, 0.04071265, 1.        , ..., 0.00843701, 0.01004329,
#         0.02761358],
#        ...,
#        [0.00755015, 0.06907149, 0.00843701, ..., 1.        , 0.00454169,
#         0.0056754 ],
#        [0.00504998, 0.01641236, 0.01004329, ..., 0.00454169, 1.        ,
#         0.0031309 ],
#        [0.00573448, 0.00929048, 0.02761358, ..., 0.0056754 , 0.0031309 ,
#         1.        ]])

# %%
# Cosine similarity score matrix
# Scores ranging from 0 to 1, where 1 being the movie is exactly same, and 0 means no similarity.
# Movie ids are added to for easy lookup.
similarity_df = pd.DataFrame(cosine_sim, columns=movies_df['id'], index=movies_df['id']).reset_index()
similarity_df
# Out:
# id           id     862.0    8844.0   15602.0   31357.0   11862.0     949.0  \
# 0         862.0  1.000000  0.019139  0.014867  0.012351  0.014120  0.007110
# 1        8844.0  0.019139  1.000000  0.040713  0.007309  0.018797  0.045300
# 2       15602.0  0.014867  0.040713  1.000000  0.010030  0.032551  0.024028
# 3       31357.0  0.012351  0.007309  0.010030  1.000000  0.008058  0.013818
# 4       11862.0  0.014120  0.018797  0.032551  0.008058  1.000000  0.009362
# ...         ...       ...       ...       ...       ...       ...       ...
# 45428  439050.0  0.004989  0.005505  0.005575  0.014423  0.000000  0.015148
# 45429  111109.0  0.000000  0.026907  0.000000  0.017853  0.000000  0.006830
# 45430   67758.0  0.007550  0.069071  0.008437  0.011153  0.023614  0.041812
# 45431  227506.0  0.005050  0.016412  0.010043  0.006520  0.008070  0.000552
# 45432  461257.0  0.005734  0.009290  0.027614  0.022422  0.003703  0.003477
#
# id      11860.0   45325.0    9091.0  ...   84419.0  390959.0  289923.0  \
# 0      0.009000  0.008515  0.005452  ...  0.008681  0.004507  0.018899
# 1      0.022838  0.015295  0.089024  ...  0.009799  0.001815  0.013434
# 2      0.013442  0.009515  0.008254  ...  0.006318  0.001838  0.005374
# 3      0.014304  0.017594  0.004176  ...  0.006656  0.001936  0.008514
# 4      0.074206  0.007399  0.050070  ...  0.011691  0.002166  0.010071
# ...         ...       ...       ...  ...       ...       ...       ...
# 45428  0.000000  0.011304  0.000000  ...  0.005868  0.005547  0.000000
# 45429  0.004749  0.001646  0.000000  ...  0.005483  0.005183  0.000000
# 45430  0.014806  0.033377  0.107624  ...  0.024813  0.003320  0.009706
# 45431  0.006945  0.004151  0.000423  ...  0.003244  0.003066  0.000574
# 45432  0.003512  0.002690  0.002666  ...  0.013095  0.010761  0.038235
#
# id     222848.0   30840.0  439050.0  111109.0   67758.0  227506.0  461257.0
# 0      0.003158  0.031112  0.004989  0.000000  0.007550  0.005050  0.005734
# 1      0.009871  0.029079  0.005505  0.026907  0.069071  0.016412  0.009290
# 2      0.003529  0.015638  0.005575  0.000000  0.008437  0.010043  0.027614
# 3      0.015227  0.072191  0.014423  0.017853  0.011153  0.006520  0.022422
# 4      0.007506  0.014361  0.000000  0.000000  0.023614  0.008070  0.003703
# ...         ...       ...       ...       ...       ...       ...       ...
# 45428  0.003479  0.002345  1.000000  0.010339  0.012033  0.006774  0.005664
# 45429  0.000000  0.014465  0.010339  1.000000  0.003473  0.003071  0.019356
# 45430  0.035654  0.020286  0.012033  0.003473  1.000000  0.004542  0.005675
# 45431  0.001900  0.000568  0.006774  0.003071  0.004542  1.000000  0.003131
# 45432  0.021367  0.042493  0.005664  0.019356  0.005675  0.003131  1.000000
#
# [45433 rows x 45434 columns]

# %% [markdown]
# # Movies Recommendator

# %%
# Ask the user what they have watched.
# user_input = input("Enter all the movies you have watched. Use comma to seperate.")
# user_input = [title.strip() for title in user_input.split(',')]
user_input = ['The Avengers', 'Black Widow', 'Black Widow', 'The Shawshank Redemption']

# %%
# Convert to movie id.
watched_movies_id = movies_df.loc[movies_df['title'].isin(user_input),'id'].tolist()
watched_movies_id
# Out:
# [278.0, 9320.0, 19345.0, 44052.0, 24428.0, 255577.0]

# %%
# Create an empty dataframe to store all the similar movies and readjust the weights
rank_similarity = pd.DataFrame(columns=['id','weights'])

# Iterate through each watched movie id to find similar movies.
for movie_id in watched_movies_id:
    # Select movies that have similarity scores above the average for the current movie.
    temp_df = pd.DataFrame(similarity_df.loc[similarity_df[movie_id] >= similarity_df[movie_id].mean(), ['id', movie_id]])
    # Rename similarity scores to weights
    temp_df = temp_df.rename(columns = {movie_id:'weights'})
    # Exclue the movie user has watched. System will not recommend what user has already watched.
    temp_df = temp_df.loc[temp_df['id'] != movie_id,:]
    # Save similar movies to a rank_similarity dataframe
    rank_similarity = pd.concat([rank_similarity, temp_df])

# Check how many movies are repeated. Higher repetation means higher interest.
rank_similarity['id'].value_counts()

# If a particular movie id is repeated, then they should be very relevant. Add the weights to rank higher.
rank_similarity['weights'] = rank_similarity.groupby(['id'])['weights'].transform('sum')

# All same movie ids will have equal weights. Drop the duplicates and show top 10 highest similarity.
top10similar = rank_similarity.drop_duplicates().sort_values(by='weights', ascending=False).head(10)
top10similar
# Out:
# /var/folders/3_/ft87w8295r1_dk2lx99fbc0h0000gn/T/ipykernel_84414/4066873631.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rank_similarity = pd.concat([rank_similarity, temp_df])
#              id   weights
# 42979   14611.0  0.679593
# 25399  118134.0  0.642400
# 30718   14613.0  0.633910
# 26540   99861.0  0.607356
# 8354    43689.0  0.595584
# 10822   14609.0  0.575919
# 23037  100402.0  0.571668
# 5016    56133.0  0.483224
# 23048  257346.0  0.469892
# 36905   30345.0  0.461167

# %%
# Show Result
print(f"Based on movies you have watched: {user_input}, these are your recommendations:")
pd.merge(top10similar, movies_df[['id', 'title', 'overview']], on='id', how='left')[['title', 'overview']]
# Out:
# Based on movies you have watched: ['The Avengers', 'Black Widow', 'Black Widow', 'The Shawshank Redemption'], these are your recommendations:
#                                            title  \
# 0                            Ultimate Avengers 2
# 1                         The Widow From Chicago
# 2              Next Avengers: Heroes of Tomorrow
# 3                        Avengers: Age of Ultron
# 4                                The Merry Widow
# 5                              Ultimate Avengers
# 6            Captain America: The Winter Soldier
# 7                                  Black Like Me
# 8  Avengers Confidential: Black Widow & Punisher
# 9                               The Black Castle
#
#                                             overview
# 0  Mysterious Wakanda lies in the darkest heart o...
# 1  A woman infiltrates a criminal mob to avenge h...
# 2  The children of the Avengers hone their powers...
# 3  When Tony Stark tries to jumpstart a dormant p...
# 4  A prince from a small kingdom courts a wealthy...
# 5  When a nuclear missile was fired at Washington...
# 6  After the cataclysmic events in New York with ...
# 7  Black Like Me is the true account of John Grif...
# 8  When the Punisher takes out a black-market wea...
# 9  A Man investigates the disappearance of two of...
